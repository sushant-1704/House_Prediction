# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Sushant Shankar\Downloads\housing.csv\housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(["median_house_value"], axis=1)
y = data["median_house_value"]

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8643     -118.40     33.88                42.0       1516.0           341.0
# 16914    -122.36     37.54                23.0       6184.0           747.0
# 2783     -118.18     37.35                16.0       3806.0           794.0
# 5283     -118.46     34.06                20.0       5448.0          1532.0
# 14105    -117.10     32.75                15.0       2422.0           774.0
# ...          ...       ...                 ...          ...             ...
# 4032     -118.54     34.17                25.0       3352.0           891.0
# 2645     -124.14     40.57                29.0       2864.0           600.0
# 9553     -120.64     37.38                21.0       3157.0           637.0
# 11843    -120.93     39.96                15.0       1666.0           351.0
# 15954    -122.45     37.71                46.0       2559.0           506.0
#
#        population  households  median_income ocean_proximity  \
# 8643        634.0       327.0         6.2356       <1H OCEAN
# 16914      2165.0       700.0        10.1675      NEAR OCEAN
# 2783       1501.0       714.0         2.1212          INLAND
# 5283       2202.0      1442.0         4.2554       <1H OCEAN
# 14105      2120.0       715.0         1.0617      NEAR OCEAN
# ...           ...         ...            ...             ...
# 4032       1815.0       860.0         2.8528       <1H OCEAN
# 2645       1314.0       562.0         2.1354       <1H OCEAN
# 9553       2268.0       620.0         2.5670          INLAND
# 11843       816.0       316.0         2.9559          INLAND
# 15954      1562.0       498.0         4.3846      NEAR OCEAN
#
#        median_house_value
# 8643             472700.0
# 16914            500001.0
# 2783             108300.0
# 5283             500001.0
# 14105             92400.0
# ...                   ...
# 4032             425000.0
# 2645              75100.0
# 9553              70400.0
# 11843            118800.0
# 15954            270600.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
tr_data = train_data.drop(["ocean_proximity"], axis=1)
tr_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925091           -0.108896     0.043241
# latitude            -0.925091  1.000000            0.011460    -0.033240
# housing_median_age  -0.108896  0.011460            1.000000    -0.359861
# total_rooms          0.043241 -0.033240           -0.359861     1.000000
# total_bedrooms       0.066575 -0.063899           -0.318911     0.930106
# population           0.094099 -0.103077           -0.292854     0.854384
# households           0.052578 -0.067598           -0.302039     0.918458
# median_income       -0.015349 -0.077618           -0.116485     0.192753
# median_house_value  -0.047672 -0.140602            0.106062     0.129746
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.066575    0.094099    0.052578      -0.015349
# latitude                 -0.063899   -0.103077   -0.067598      -0.077618
# housing_median_age       -0.318911   -0.292854   -0.302039      -0.116485
# total_rooms               0.930106    0.854384    0.918458       0.192753
# total_bedrooms            1.000000    0.875680    0.979743      -0.010781
# population                0.875680    1.000000    0.905257       0.000652
# households                0.979743    0.905257    1.000000       0.010197
# median_income            -0.010781    0.000652    0.010197       1.000000
# median_house_value        0.048198   -0.027252    0.063414       0.688414
#
#                     median_house_value
# longitude                    -0.047672
# latitude                     -0.140602
# housing_median_age            0.106062
# total_rooms                   0.129746
# total_bedrooms                0.048198
# population                   -0.027252
# households                    0.063414
# median_income                 0.688414
# median_house_value            1.000000

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(tr_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
tr_data["total_rooms"] = np.log(tr_data["total_rooms"]+1)
tr_data["total_bedrooms"] = np.log(tr_data["total_bedrooms"]+1)
tr_data["population"] = np.log(tr_data["population"]+1)
tr_data["households"] = np.log(tr_data["households"]+1)

# %%
tr_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7249
# INLAND        5235
# NEAR OCEAN    2061
# NEAR BAY      1797
# ISLAND           4
# Name: count, dtype: int64

# %%
print(train_data.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity', 'median_house_value'],
#       dtype='object')

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(["ocean_proximity"], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8643     -118.40     33.88                42.0       1516.0           341.0
# 16914    -122.36     37.54                23.0       6184.0           747.0
# 2783     -118.18     37.35                16.0       3806.0           794.0
# 5283     -118.46     34.06                20.0       5448.0          1532.0
# 14105    -117.10     32.75                15.0       2422.0           774.0
# ...          ...       ...                 ...          ...             ...
# 4032     -118.54     34.17                25.0       3352.0           891.0
# 2645     -124.14     40.57                29.0       2864.0           600.0
# 9553     -120.64     37.38                21.0       3157.0           637.0
# 11843    -120.93     39.96                15.0       1666.0           351.0
# 15954    -122.45     37.71                46.0       2559.0           506.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 8643        634.0       327.0         6.2356            472700.0       True
# 16914      2165.0       700.0        10.1675            500001.0      False
# 2783       1501.0       714.0         2.1212            108300.0      False
# 5283       2202.0      1442.0         4.2554            500001.0       True
# 14105      2120.0       715.0         1.0617             92400.0      False
# ...           ...         ...            ...                 ...        ...
# 4032       1815.0       860.0         2.8528            425000.0       True
# 2645       1314.0       562.0         2.1354             75100.0       True
# 9553       2268.0       620.0         2.5670             70400.0      False
# 11843       816.0       316.0         2.9559            118800.0      False
# 15954      1562.0       498.0         4.3846            270600.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 8643    False   False     False       False
# 16914   False   False     False        True
# 2783     True   False     False       False
# 5283    False   False     False       False
# 14105   False   False     False        True
# ...       ...     ...       ...         ...
# 4032    False   False     False       False
# 2645    False   False     False       False
# 9553     True   False     False       False
# 11843    True   False     False       False
# 15954   False   False     False        True
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x="latitude", y="longitude",data=train_data, hue="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop(["median_house_value"], axis=1), train_data["median_house_value"]
X_train_s = scaler.fit_transform(X_train)


reg = LinearRegression()

reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

tr_data["total_rooms"] = np.log(tr_data["total_rooms"]+1)
tr_data["total_bedrooms"] = np.log(tr_data["total_bedrooms"]+1)
tr_data["population"] = np.log(tr_data["population"]+1)
tr_data["households"] = np.log(tr_data["households"]+1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(["ocean_proximity"], axis=1)

test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13897    -116.29     34.18                15.0       4203.0           966.0
# 14443    -117.25     32.80                26.0       2442.0           659.0
# 430      -122.28     37.88                52.0       1172.0           215.0
# 16925    -122.31     37.58                44.0       1990.0           442.0
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# ...          ...       ...                 ...          ...             ...
# 6094     -117.88     34.12                33.0       1485.0           274.0
# 17676    -121.84     37.32                14.0       5762.0          1538.0
# 5527     -118.41     33.97                44.0       2298.0           388.0
# 19455    -120.95     37.66                16.0       4478.0           647.0
# 2242     -119.78     36.83                11.0       2754.0           663.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13897      1756.0       695.0         2.1820             60800.0      False
# 14443      1134.0       624.0         3.3274            295500.0      False
# 430         489.0       218.0         3.9167            235600.0      False
# 16925      1141.0       424.0         3.9696            258300.0      False
# 5241       2184.0       960.0         8.2816            500001.0       True
# ...           ...         ...            ...                 ...        ...
# 6094       1006.0       258.0         5.1708            158500.0       True
# 17676      3979.0      1389.0         3.6953            192600.0       True
# 5527        849.0       360.0         5.5941            363500.0       True
# 19455      1990.0       672.0         5.1473            188400.0      False
# 2242       1328.0       604.0         2.3667             69300.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 13897    True   False     False       False       0.229836         6.047482
# 14443   False   False     False        True       0.269861         3.913462
# 430     False   False      True       False       0.183447         5.376147
# 16925   False   False      True       False       0.222111         4.693396
# 5241    False   False     False       False       0.156972         6.715625
# ...       ...     ...       ...         ...            ...              ...
# 6094    False   False     False       False       0.184512         5.755814
# 17676   False   False     False       False       0.266921         4.148308
# 5527    False   False     False       False       0.168842         6.383333
# 19455    True   False     False       False       0.144484         6.663690
# 2242     True   False     False       False       0.240741         4.559603
#
# [4087 rows x 16 columns]

# %%
X_test, y_test = test_data.drop(["median_house_value"], axis=1), test_data["median_house_value"]

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6559830459310576

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8236177060866212

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

param_grid = {
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}

grid_search = GridSearchCV(forest, param_grid,cv=5,scoring="neg_mean_squared_error",return_train_score=True)

grid_search.fit(X_test_s, y_test)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.9651076514559725
